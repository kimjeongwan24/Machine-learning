# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-52sqwbil
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-52sqwbil
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
  def forward(self, x):
      h1 = self.linear1(x)
      h2 = h1 + self.linear2(torch.relu(h1))
      h3 = h2 + self.linear3(torch.relu(h2))
      return self.linear4(torch.relu(h3))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, \
  train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.552288, train error 60.22,  val loss 1.651681, percent error 65.70
# Epoch     1, train loss 1.260606, train error 46.22,  val loss 1.464077, percent error 55.70
# Epoch     2, train loss 1.091449, train error 40.70,  val loss 1.370914, percent error 53.20
# Epoch     3, train loss 0.892162, train error 31.65,  val loss 1.263974, percent error 49.30
# Epoch     4, train loss 0.793544, train error 28.40,  val loss 1.244228, percent error 48.10
# Epoch     5, train loss 0.650596, train error 23.15,  val loss 1.224993, percent error 44.40
# Epoch     6, train loss 0.595536, train error 21.25,  val loss 1.208910, percent error 44.30
# Epoch     7, train loss 0.468165, train error 16.28,  val loss 1.132554, percent error 40.50
# Epoch     8, train loss 0.397936, train error 13.68,  val loss 1.119354, percent error 39.20
# Epoch     9, train loss 0.361678, train error 12.28,  val loss 1.162075, percent error 40.00
# Epoch    10, train loss 0.309243, train error 10.53,  val loss 1.183386, percent error 37.70
# Epoch    11, train loss 0.241896, train error 7.32,  val loss 1.114515, percent error 35.10
# Epoch    12, train loss 0.226603, train error 7.47,  val loss 1.255156, percent error 36.80
# Epoch    13, train loss 0.185425, train error 5.95,  val loss 1.246386, percent error 36.00
# Epoch    14, train loss 0.184476, train error 5.80,  val loss 1.357906, percent error 37.40
# Epoch    15, train loss 0.176300, train error 5.60,  val loss 1.477796, percent error 39.40
# Epoch    16, train loss 0.172349, train error 5.40,  val loss 1.501050, percent error 37.00
# Epoch    17, train loss 0.109684, train error 3.00,  val loss 1.481976, percent error 36.50
# Epoch    18, train loss 0.117613, train error 3.62,  val loss 1.490720, percent error 38.10
# Epoch    19, train loss 0.084709, train error 2.38,  val loss 1.485745, percent error 35.00
# Epoch    20, train loss 0.025163, train error 0.07,  val loss 1.337569, percent error 33.20
# Epoch    21, train loss 0.014880, train error 0.00,  val loss 1.350935, percent error 32.30
# Epoch    22, train loss 0.011048, train error 0.00,  val loss 1.391236, percent error 32.40
# Epoch    23, train loss 0.009325, train error 0.00,  val loss 1.416324, percent error 32.00
# Epoch    24, train loss 0.008115, train error 0.00,  val loss 1.434868, percent error 32.10
# Epoch    25, train loss 0.007324, train error 0.00,  val loss 1.451077, percent error 32.30
# Epoch    26, train loss 0.006687, train error 0.00,  val loss 1.463462, percent error 32.40
# Epoch    27, train loss 0.006148, train error 0.00,  val loss 1.477727, percent error 32.60
# Epoch    28, train loss 0.005707, train error 0.00,  val loss 1.490299, percent error 32.60
# Epoch    29, train loss 0.005320, train error 0.00,  val loss 1.503380, percent error 32.50
# Epoch    30, train loss 0.005005, train error 0.00,  val loss 1.517224, percent error 32.60
# Epoch    31, train loss 0.004712, train error 0.00,  val loss 1.523606, percent error 32.50
# Epoch    32, train loss 0.004460, train error 0.00,  val loss 1.533929, percent error 32.50
# Epoch    33, train loss 0.004244, train error 0.00,  val loss 1.545346, percent error 32.60
# Epoch    34, train loss 0.004032, train error 0.00,  val loss 1.551718, percent error 32.60
# Epoch    35, train loss 0.003850, train error 0.00,  val loss 1.560855, percent error 32.40
# Epoch    36, train loss 0.003691, train error 0.00,  val loss 1.567835, percent error 32.50
# Epoch    37, train loss 0.003537, train error 0.00,  val loss 1.575439, percent error 32.50
# Epoch    38, train loss 0.003390, train error 0.00,  val loss 1.583454, percent error 32.50
# Epoch    39, train loss 0.003276, train error 0.00,  val loss 1.593040, percent error 32.60
# Epoch    40, train loss 0.003198, train error 0.00,  val loss 1.594577, percent error 32.40
# Epoch    41, train loss 0.003138, train error 0.00,  val loss 1.598346, percent error 32.30
# Epoch    42, train loss 0.003082, train error 0.00,  val loss 1.601007, percent error 32.30
# Epoch    43, train loss 0.003027, train error 0.00,  val loss 1.604889, percent error 32.50
# Epoch    44, train loss 0.002976, train error 0.00,  val loss 1.608074, percent error 32.50
# Epoch    45, train loss 0.002924, train error 0.00,  val loss 1.611252, percent error 32.60
# Epoch    46, train loss 0.002877, train error 0.00,  val loss 1.614167, percent error 32.40
# Epoch    47, train loss 0.002830, train error 0.00,  val loss 1.617135, percent error 32.40
# Epoch    48, train loss 0.002782, train error 0.00,  val loss 1.620339, percent error 32.40
# Epoch    49, train loss 0.002738, train error 0.00,  val loss 1.622931, percent error 32.40
# Epoch    50, train loss 0.002695, train error 0.00,  val loss 1.626419, percent error 32.80
# Epoch    51, train loss 0.002653, train error 0.00,  val loss 1.628401, percent error 32.40
# Epoch    52, train loss 0.002613, train error 0.00,  val loss 1.632452, percent error 32.70
# Epoch    53, train loss 0.002573, train error 0.00,  val loss 1.634454, percent error 33.00
# Epoch    54, train loss 0.002534, train error 0.00,  val loss 1.637512, percent error 32.60
# Epoch    55, train loss 0.002498, train error 0.00,  val loss 1.639727, percent error 32.80
# Epoch    56, train loss 0.002462, train error 0.00,  val loss 1.643471, percent error 32.90
# Epoch    57, train loss 0.002427, train error 0.00,  val loss 1.645995, percent error 33.00
# Epoch    58, train loss 0.002392, train error 0.00,  val loss 1.648673, percent error 32.80
# Epoch    59, train loss 0.002359, train error 0.00,  val loss 1.651131, percent error 32.90
# Epoch    60, train loss 0.002342, train error 0.00,  val loss 1.652747, percent error 33.10
# Epoch    61, train loss 0.002326, train error 0.00,  val loss 1.653760, percent error 33.00
# Epoch    62, train loss 0.002311, train error 0.00,  val loss 1.654876, percent error 33.00
# Epoch    63, train loss 0.002295, train error 0.00,  val loss 1.656267, percent error 32.90
# Epoch    64, train loss 0.002280, train error 0.00,  val loss 1.657636, percent error 33.10
# Epoch    65, train loss 0.002265, train error 0.00,  val loss 1.659288, percent error 33.00
# Epoch    66, train loss 0.002250, train error 0.00,  val loss 1.660503, percent error 33.00
# Epoch    67, train loss 0.002235, train error 0.00,  val loss 1.661578, percent error 32.80
# Epoch    68, train loss 0.002220, train error 0.00,  val loss 1.662654, percent error 32.80
# Epoch    69, train loss 0.002206, train error 0.00,  val loss 1.663881, percent error 32.80
# Epoch    70, train loss 0.002192, train error 0.00,  val loss 1.665006, percent error 32.90
# Epoch    71, train loss 0.002178, train error 0.00,  val loss 1.666301, percent error 32.90
# Epoch    72, train loss 0.002165, train error 0.00,  val loss 1.667722, percent error 32.80
# Epoch    73, train loss 0.002151, train error 0.00,  val loss 1.668783, percent error 32.80
# Epoch    74, train loss 0.002137, train error 0.00,  val loss 1.670200, percent error 32.70
# Epoch    75, train loss 0.002124, train error 0.00,  val loss 1.670864, percent error 32.80
# Epoch    76, train loss 0.002111, train error 0.00,  val loss 1.672001, percent error 32.80
# Epoch    77, train loss 0.002098, train error 0.00,  val loss 1.673428, percent error 32.70
# Epoch    78, train loss 0.002085, train error 0.00,  val loss 1.674652, percent error 32.90
# Epoch    79, train loss 0.002073, train error 0.00,  val loss 1.675807, percent error 32.80
# Epoch    80, train loss 0.002066, train error 0.00,  val loss 1.676512, percent error 32.80
# Epoch    81, train loss 0.002060, train error 0.00,  val loss 1.677322, percent error 32.80
# Epoch    82, train loss 0.002054, train error 0.00,  val loss 1.677703, percent error 32.90
# Epoch    83, train loss 0.002048, train error 0.00,  val loss 1.678212, percent error 32.80
# Epoch    84, train loss 0.002042, train error 0.00,  val loss 1.678745, percent error 32.80
# Epoch    85, train loss 0.002036, train error 0.00,  val loss 1.679417, percent error 32.90
# Epoch    86, train loss 0.002030, train error 0.00,  val loss 1.679823, percent error 32.90
# Epoch    87, train loss 0.002024, train error 0.00,  val loss 1.680343, percent error 32.90
# Epoch    88, train loss 0.002018, train error 0.00,  val loss 1.680765, percent error 32.90
# Epoch    89, train loss 0.002012, train error 0.00,  val loss 1.681561, percent error 32.90
# Epoch    90, train loss 0.002006, train error 0.00,  val loss 1.681929, percent error 32.90
# Epoch    91, train loss 0.002000, train error 0.00,  val loss 1.682713, percent error 33.00
# Epoch    92, train loss 0.001994, train error 0.00,  val loss 1.682985, percent error 33.00
# Epoch    93, train loss 0.001988, train error 0.00,  val loss 1.683901, percent error 32.90
# Epoch    94, train loss 0.001983, train error 0.00,  val loss 1.684268, percent error 33.00
# Epoch    95, train loss 0.001977, train error 0.00,  val loss 1.684647, percent error 32.90
# Epoch    96, train loss 0.001971, train error 0.00,  val loss 1.685419, percent error 33.00
# Epoch    97, train loss 0.001966, train error 0.00,  val loss 1.686088, percent error 33.00
# Epoch    98, train loss 0.001960, train error 0.00,  val loss 1.686321, percent error 33.00
# Epoch    99, train loss 0.001954, train error 0.00,  val loss 1.686977, percent error 32.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
